# %%
pip install opendatasets

# %%
#used besthamuralikrishnavyas@gmail for kaggle sign in
# api token :   KGAT_58830291eeabf14f257909982017a0d3
# user name : muralikrishnavyas

# %%
# %sql
create catalog  IF not exists bronze;
use catalog bronze;
create schema if not exists stage;
create volume if not exists stage.raw;

# %%
import opendatasets as od

# Use the full Kaggle dataset URL (or competition URL)
dataset_url = "https://www.kaggle.com/datasets/aaronweymouth/nyc-rideshare-raw-data"  # Replace with yours

download_path = '/Volumes/bronze/stage/raw/NYC_Data' # Note: /dbfs/ for direct access

od.download(dataset_url, download_path)
